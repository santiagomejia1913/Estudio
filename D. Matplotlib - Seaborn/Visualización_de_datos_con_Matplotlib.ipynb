# %% [markdown]
# #MATPLOTLIB

# %% [markdown]
# ## 1.Pyplot Basico

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ###1.1Graficos de linea

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(x,y,'r')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(x,y,'bo') #"b"-->blue; "x"--> Puntos como bolitas
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(x,y,'yx') #"y"-->yellow; "x"--> Puntos como x
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(x,y,'rs-') #"r"-->red; "s"--> Puntos cuadrados; "-" Linea continua
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(x,y,'yD:') #"y"-->yellow; "D"--> Diamante; ":" Consecución de puntos
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ###1.2Histogramas

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# ###1.3Grafico de Pie

# %%
plt.pie(x)
plt.show()

# %% [markdown]
# ###1.4Grafico de dispersión

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ###1.5 Boxplot

# %%
plt.boxplot(x)
plt.show()

# %% [markdown]
# ##2.Subplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
plt.subplot(1,2,1) #1er argumento: # de filas de graficos; 2do argumento: # de columnas de graficos; 3er argumento: index entre filas y columna (Para este caso se crearian 2 index porque son 2 graficas)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.hist(y)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.subplot(1,2,1) 
plt.plot(x,y,'r--')
plt.plot(y,x,'b:')
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %%
plt.subplot(2,1,1) 
plt.plot(x,y,'r--')
plt.plot(y,x,'b:')
plt.subplot(2,1,2)
plt.pie(y)
plt.show()

# %%
#EJEMPLO DE COMPAÑERO QUE ME LLAMO LA ATENCIÓN - NO ES DE LA CLASE

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec

fig = plt.figure(tight_layout=True)
gs = gridspec.GridSpec(2, 2) # 2 filas x 2 columnas 
ax = fig.add_subplot(gs[0, :]) # comparto toda la fila 0
ax.hist(y) 
ax = fig.add_subplot(gs[1, 0])
ax.plot(x,y,'r--')  
ax = fig.add_subplot(gs[1, 1])
ax.plot(y,x,'b:') 
plt.show()

# %% [markdown]
# ##3.Método orientado a objetos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Figure: Es el linzo.
# - Axes: Es la grafica.
# - Axis: Son los ejes de la grafica.

# %%
fig = plt.figure() #En el método orientado a objetos primero se crea un lienzo con esta sentencia. 
axes = fig.add_axes([0.1,0.1,0.2,0.9]) #Los primeros dos parametros "0.1,0.1" hacen referencia a la posición en el lienzo. Los siguientes dos hacen referencia al tamaño que va a tener la figura en ese lienzo. 
#Tener en cuenta que cuando solo es una figura, los primeros dos parametros, no hacen efecto. Sin embargo para dos figuras si que sirven como se verá en el siguiente ejemplo
axes.plot(x,y,'b')
fig.show()

# %%
fig = plt.figure() #En el método orientado a objetos primero se crea un lienzo con esta sentencia. 
axes = fig.add_axes([0.1,0.1,0.8,0.9])
axes2 = fig.add_axes([0.1,0.1,0.4,0.3])

axes.plot(x,y,'b')
axes2.plot(y,x,'r')
fig.show()

# %%
fig = plt.figure() #En el método orientado a objetos primero se crea un lienzo con esta sentencia. 
axes = fig.add_axes([0.1,0.1,0.8,0.9])
axes2 = fig.add_axes([0.2,0.6,0.4,0.3])

axes.plot(x,y,'b')
axes2.plot(y,x,'r')
axes2.set_facecolor('gray')
fig.show()

# %% [markdown]
# Aspectos personalizables usando el método "orientado a objetos"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4.Subplots

# %% [markdown]
# La diferencia entres "subplot" y "subplots" es que la 2da es para plotear varias graficas pero en el método orientado a objetos.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
#axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,'b') #axes[0]-->Hace referencia al primer grafico, el de indice 0. 
axes[1].plot(y,x,'r')

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2) #Tambien puedo definir una tupla "(ax1,ax2)" pero obvio debe coincidir con la cantidad de graficos que defina en nrows y ncols
ax1.plot(x,y,'b') 
ax2.plot(y,x,'r')

# %%
fig, axes = plt.subplots(2, 4) #Poner nrows y ncols es opcional
axes[0,0].plot(x,np.cos(x),'b') 
axes[0,1].plot(x,np.sin(x),'y') 
axes[0,2].plot(x,np.tan(x),'r') 
axes[0,3].plot(x,np.cos(x)**2,'b')

# %%
fig, ((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(2, 4) #Poner nrows y ncols es opcional
ax1.plot(x,np.cos(x),'b') 
ax2.plot(x,np.sin(x),'y') 
ax3.plot(x,np.tan(x),'r') 
ax4.plot(x,np.cos(x)**2,'b') 
fig.tight_layout() # Para que se organicen de mejor manera las graficas

# %% [markdown]
# ##5.Leyendas, etiquetas, titulos y Tamaño

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,5))
axes[0].plot(x,y, label="sin(x)") # Defino los labels (Leyenda)en la grafica y despues debo ejecutar "axes[0].legend()"
axes[0].set_title('Relacion X - Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].legend()

axes[1].plot(y,x)
axes[1].set_title('Relacion Y - X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
# Out:
# Text(0, 0.5, 'X')

# %%
#PARA Pyplot Basico
plt.plot(x,y,label="$sin(x)$") #El simbolo de pesos hace que la leyenda use notación matematica
plt.title("Este es un titulo")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc='lower left', bbox_to_anchor=(1,0.9))

# %% [markdown]
# ##6.Colores y estilos

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)

# %%
print(plt.style.available) # Diferentes estilos predefinidos de graficos.
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
#Por si quiero vero todos los estilos anteriores
for i in plt.style.available:
  plt.style.use(i)
  fig, ax = plt.subplots(figsize=(5,5))
  ax.plot(x, y)

# %%
plt.style.use('bmh')

# %%
fig, ax = plt.subplots(figsize=(8,8))

# %%
plt.style.use('dark_background')

# %% [markdown]
# ### 6.1 Estilo Matlab

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x,x+1,'r--')
ax.plot(x,x+2,'b-')
ax.plot(x,x+3,'y.-')
ax.plot(x,x+4,'go:')

# %% [markdown]
# ### 6.2 Estilo Pyplot

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x,x+1, color = 'green', alpha = 1, linewidth=5, linestyle="-", marker='o', markersize = 10, markerfacecolor='#CCFFCC') #alpha: Transparencia del color
ax.plot(x,x+2, color = 'blue', linewidth=3, linestyle="--", marker='x', markersize = 4)
ax.plot(x,x+3, color = '#66FF66', linewidth=8, linestyle="dashed", marker='v') #RGB
ax.plot(x,x+4, color = '#CCFFCC', linewidth=1, linestyle=":", marker='P')

# %% [markdown]
# ##7.Bar Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
country = ['INDIA', 'JAPAN', 'MEXICO', 'COLOMBIA', 'GERMANY']
population = [1000, 800, 900, 1000, 300]

# %%
plt.bar(country, population, width=0.5, color=['red', 'blue'])
plt.xticks(np.arange(5),('India', 'Japon', 'Mexico', 'Colombia', 'Alemania'), rotation=45) #Por si quiero cambiar los nombres del eje a como venian originalmente
#Rotation es para el angulo de los nombre del eje. 
plt.show()

# %%
plt.barh(country, population)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Para saber mas:
#
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# %% [markdown]
# ## 8.Otros tipos de graficos

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(1,50,100)

# %%
data
# Out:
# array([44, 36, 15, 30, 19, 41, 43, 48, 12, 26, 49, 10, 44, 40, 25, 44, 36,
#        14, 37, 19, 20,  4, 41, 28, 14, 13,  8,  7, 30, 34,  3, 29, 25, 13,
#         4, 30, 45, 41, 30, 18, 22, 13, 30, 46,  8, 10, 14, 41,  4, 36, 30,
#        11, 41,  5,  2, 16,  9, 16, 39, 18, 39, 12,  9, 40,  6, 30, 36, 25,
#        48, 11, 28,  1, 19,  4, 35,  6, 14, 30, 29, 37,  7, 15,  7, 45, 44,
#        24, 28, 48,  1, 25, 32, 38, 11, 37, 32, 23, 11, 43, 33, 29])

# %% [markdown]
# ###8.1Histograma

# %%
plt.hist(data, bins=50, width=1) #bins --> Numero de barras
plt.show()

# %%
plt.hist(data, bins=50, histtype='step') #bins --> Numero de barras
plt.show()

# %% [markdown]
# ###8.2 Boxplot

# %%
data = np.append(data, 200)
plt.boxplot(data, vert=False, patch_artist=True, notch = True, showfliers=False) #notch --> Hace el embudito; patch_artist --> Para rellenar el grafico de boxplot
#showfliers=False: Hace que no me muestre los outliers
plt.show()

# %% [markdown]
# ### 8.3 Grafico de dispersión

# %%
N=50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30*np.random.rand(N))**2
colors = np.random.rand(N)

# %%
plt.scatter(x,y, s=area, c=colors, marker='p', alpha=0.5)
plt.show()
