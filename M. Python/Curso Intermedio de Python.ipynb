# %% [markdown]
# # Curso Intermedio de Python

# %% [markdown]
# ##1.Crear un entorno virtual

# %% [markdown]
# Creando un ambiente virtual con VENV
#
# Creación de ambiente Virtual:
#
# 1. py -m venv nombre_venv
#
# Usualmente el nombre del ambiente virtual es venv.
# 2. Activación del ambiente virtual:
#
# Windows:
# .\venv\Scripts\activate
#
# Unix o MacOS:
# source venv/bin/activate
#
# 3. Desactivar el ambiente virtual:
#
# deactivate
#
# 4. Crear un alias en windows (Para no tener que copiar otra vez lo del punto 2)
#
# alias avenv=.\venv\Scripts\activate

# %% [markdown]
# ##2.Instalador de dependencias con PIP

# %% [markdown]
# Todo lo que instalemos con PIP que hagamos dentro de nuestro ambiente virtual, solo estará disponble para, efectivamente, nuestro ambiente virtual.
#
# pip freeze --> Para ver que tenemos instalado en nuestro ambiente virtual.
#
# pip install pandas --> Para Instalar una dependencia. En este caso, pandas.
#
# pip freeze > requirements.txt --> Guardar las dependencias que tengo en mi entorno virtual para poder compartirlo con otra persona.
#
# pip install -r requirements.txt --> Para instalar los modulos que esten en el archivo requirements

# %% [markdown]
# ##3.Listas y diccionarios anidados

# %%
def run():
    my_list = [1, 'hello', True, 4.5]
    my_dict = {"firstname":"Facundo", "lastname":"Garcia"}

    super_list = [
        {"firstname":"Facundo", "lastname":"Garcia"},
        {"firstname":"Miguel", "lastname":"Torres"},
        {"firstname":"Pepe", "lastname":"Rodelo"},
        {"firstname":"Susana", "lastname":"Martinez"},
        {"firstname":"Jose", "lastname":"Garcia"}
    ]

    super_dict = {
        "natural_nums": [1,2,3,4,5],
        "integer_nums": [-1,-2,0,1,2],
        "floating_nums": [1.1, 4.5, 6.43]
    }

    for key, value in super_dict.items():
        print(key, "-", value)

if __name__=='__main__':
    run()
# Out:
# natural_nums - [1, 2, 3, 4, 5]
# integer_nums - [-1, -2, 0, 1, 2]
# floating_nums - [1.1, 4.5, 6.43]

# %% [markdown]
# ##4.List Comprehension

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def run():
#    sq_nums = []
#    for i in range(0,100):
#        if i*3 != 0:
#            sq_nums.append(i**2)
# Lo anterior se resume con el siguiente list_comprehension. Ejemplo para elementos
# del 1 al 100 que se eleven al cuadrado y no sean multiplos de 3.
    sq_nums = [i**2 for i in range(1, 101) if i % 3 != 0]
# RETO: Crear list comprenhension de todos los multiplos de 4 que a la vez tambien son multiplos
# de 6 y de 9 hasta 5 digitos.

    reto = [4*i for i in range(1,9999) if (4*i) % 6 == 0 and (4*i) % 9 == 0]

    print(sq_nums)
    print(reto)

if __name__ == "__main__":
    run()
# Out:
# [1, 4, 16, 25, 49, 64, 100, 121, 169, 196, 256, 289, 361, 400, 484, 529, 625, 676, 784, 841, 961, 1024, 1156, 1225, 1369, 1444, 1600, 1681, 1849, 1936, 2116, 2209, 2401, 2500, 2704, 2809, 3025, 3136, 3364, 3481, 3721, 3844, 4096, 4225, 4489, 4624, 4900, 5041, 5329, 5476, 5776, 5929, 6241, 6400, 6724, 6889, 7225, 7396, 7744, 7921, 8281, 8464, 8836, 9025, 9409, 9604, 10000]
# ...

# %% [markdown]
# ##5.Dictionary Comprehensions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math

def run():
    ## Crear un diccionario cuyas llaves sean los primeros 100 numeros naturales y cuyos valores sean esos
    #numeros elevados al cubo. Sin elementos que sean divisibles por 3
    
    dic_ent = {}
    for i in range(1,101):
        if i%3 != 0:
            dic_ent[i] = i**3
     
    print(dic_ent)

    #Lo anterior con dict comprehension

    my_dic = {i: i**3 for i in range(1,101) if i % 3 != 0}
    print(my_dic)

    # Raiz cuadrada de los mil primerios numeros naturales 
    my_dic_reto = {i: math.sqrt(i) for i in range(1,101)}
    print(my_dic_reto)
if __name__ == "__main__":
    run()
# Out:
# {1: 1, 2: 8, 4: 64, 5: 125, 7: 343, 8: 512, 10: 1000, 11: 1331, 13: 2197, 14: 2744, 16: 4096, 17: 4913, 19: 6859, 20: 8000, 22: 10648, 23: 12167, 25: 15625, 26: 17576, 28: 21952, 29: 24389, 31: 29791, 32: 32768, 34: 39304, 35: 42875, 37: 50653, 38: 54872, 40: 64000, 41: 68921, 43: 79507, 44: 85184, 46: 97336, 47: 103823, 49: 117649, 50: 125000, 52: 140608, 53: 148877, 55: 166375, 56: 175616, 58: 195112, 59: 205379, 61: 226981, 62: 238328, 64: 262144, 65: 274625, 67: 300763, 68: 314432, 70: 343000, 71: 357911, 73: 389017, 74: 405224, 76: 438976, 77: 456533, 79: 493039, 80: 512000, 82: 551368, 83: 571787, 85: 614125, 86: 636056, 88: 681472, 89: 704969, 91: 753571, 92: 778688, 94: 830584, 95: 857375, 97: 912673, 98: 941192, 100: 1000000}
# ...

# %% [markdown]
# ##6.Funciones anonimas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Las funciones lambda solo pueden tener una linea de codigo (En python).
#
# No necesitan utilizar la palabra "return"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# De la forma tradicional. Asi seria la función

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##7.High order functions

# %% [markdown]
# Una función de orden superior es una función que recibe como parametro a otra función

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hay 3 funciones de orden superior que son muy importantes en una gran cantidad de lenguages de programación: filter, map y reduce.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### filter

# %% [markdown]
# Ejemplo: Sacar los numeros impares de una lista.
#
# De forma tradicional seria asi:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Con la función filter se haria de la siguiente manera:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### map

# %% [markdown]
# Quiero convertir los elementos de una lista elevandolos al cuadrado.
#
# De forma tradicional seria asi:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Con la función map se haria de la siguiente manera:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### reduce

# %% [markdown]
# Reduce quiero multiplicar todos los elementos de una lista (Reducir todos los valores de una lista en un solo valor)
#
# De forma tradicional seria asi:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Con la función reduce se haria de la siguiente manera:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tener en cuenta que esta es la unica función de orden superiror de las 3 a la que tengo que realizar una importación.

# %% [markdown]
# "reduce" toma 2 valores entregados como parámetros y el iterador como otro parámetro. Realiza la función con estos 2 valores, y luego con el resultado de esto y el valor que le sigue en el array. Y así hasta pasar por todos los valores de la lista. Es decir, la función de reducción necesita de dos parámetros, uno que almacena el resultado (o el primer valor del iterable) y otro que opera con el siguiente valor del iterable:

# %% [markdown]
# ## Practica: List comprenhensions - Funciones anonimas - High order functions

# %%
DATA = [
    {
        'name': 'Facundo',
        'age': 72,
        'organization': 'Platzi',
        'position': 'Technical Coach',
        'language': 'python',
    },
    {
        'name': 'Luisana',
        'age': 33,
        'organization': 'Globant',
        'position': 'UX Designer',
        'language': 'javascript',
    },
    {
        'name': 'Héctor',
        'age': 19,
        'organization': 'Platzi',
        'position': 'Associate',
        'language': 'ruby',
    },
    {
        'name': 'Gabriel',
        'age': 20,
        'organization': 'Platzi',
        'position': 'Associate',
        'language': 'javascript',
    },
    {
        'name': 'Isabella',
        'age': 30,
        'organization': 'Platzi',
        'position': 'QA Manager',
        'language': 'java',
    },
    {
        'name': 'Karo',
        'age': 23,
        'organization': 'Everis',
        'position': 'Backend Developer',
        'language': 'python',
    },
    {
        'name': 'Ariel',
        'age': 32,
        'organization': 'Rappi',
        'position': 'Support',
        'language': '',
    },
    {
        'name': 'Juan',
        'age': 17,
        'organization': '',
        'position': 'Student',
        'language': 'go',
    },
    {
        'name': 'Pablo',
        'age': 32,
        'organization': 'Master',
        'position': 'Human Resources Manager',
        'language': 'python',
    },
    {
        'name': 'Lorena',
        'age': 56,
        'organization': 'Python Organization',
        'position': 'Language Maker',
        'language': 'python',
    },
]

def run():
    all_python_devs = [worker["name"] for worker in DATA if worker["language"] == "python"] # Con list comprenhension
    all_python_devs2 = list(filter(lambda worker: worker["language"]=="python", DATA)) # Con filter y map
    all_python_devs2 = list(map(lambda worker: worker["name"], all_python_devs2))

    all_platzi_worker = [worker["name"] for worker in DATA if worker["organization"]=="Platzi"] # Con list comprenhension
    all_platzi_worker2 = list(filter(lambda worker:worker["organization"]=="Platzi", DATA)) # Con filter y map
    all_platzi_worker2 = list(map(lambda worker:worker["name"],all_platzi_worker2))

    adults = list(filter(lambda worker: worker["age"] > 18, DATA))# Con filter y map
    adults = list(map(lambda worker: worker["name"], adults)) # Para traer solo los nombres de los que cumplen la condicion
    adults2 = [worker["name"] for worker in DATA if worker["age"]>18]# Con list comprenhension
    
    #old_people = list(map(lambda worker: worker | {"old": worker["age"]>70}, DATA)) # Con filter y map --> Si funciona en Visual Studio (Puede ser la version de python)
    #old_people2 = [worker | {"old": worker["age"]>70} for worker in DATA] # Con list comprenhension --> Si funciona en Visual Studio (Puede ser la version de python)

    for worker in adults2:
        print(worker)



if __name__ == "__main__":
    run()
# Out:
# Facundo
# Luisana
# Héctor
# Gabriel
# Isabella
# Karo
# Ariel
# Pablo
# Lorena

# %% [markdown]
# ##8.Manejo de Errores

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Syntax Error** -> Errores de escritura, Python no ejecuta el programa.
#
# **Exception** -> Python se detiene en una línea en específica:
# 1. KeyboardInterrupt -> Ctrl + C
# 2. KeyError -> Cuando tratamos de acceder a una llave que no existe
# 3. IndexError -> Cuando tratamos de acceder a un índice que no existe
# 4. FileNotFoundError -> Archivo que no existe
# 5. ZeroDivisionError -> Dividir entre 0
# 6. ImportError -> Intentamos importar un módulo que tiene un error

# %% [markdown]
# Estos son solo algunos ejemplos, hay más de 50 excepciones.

# %% [markdown]
# ###Excepciones

# %% [markdown]
# #### try - except

# %% [markdown]
# Anidamos nuestro programa en dos bloques de código, el primero es el programa per se (el que se ejecuta normalmente, sin errores) y el segundo representa las instrucciones a seguir en caso de error.
# Su sintaxis es:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# -*error:* es un parámetro opcional, permite capturar sólo el tipo de error indicado, si no se coloca captura todos los errores posibles (es buena práctica capturar cada tipo de error por separado)
#
# -*as alias* nos permite crear un alias al error, para trabajar con él.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Raise

# %% [markdown]
# Esta instrucción nos permite generar errores, es decir crear nuestros propios errores cuando detectemos que nuestro programa no actúa como debería con cierto tipo de datos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Finally

# %% [markdown]
#  Es una bloque de código que se ejecuta exista un error o no (un tercer bloque después de try except), no es muy usual pero puede darse para cerrar archivos, conexiones a BBDD o liberar recursos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Una imagen que ayuda a aclarar el uso de excepciones en conjunto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def divisors(num):
    try:
        if num < 0:
            raise ValueError("No se puede ingresar numeros negativos")
        divisors = []
        for i in range(1, num +1):
            if num % i == 0:
                divisors.append(i)
        return divisors
    except ValueError as ve:
        print(ve)
        return False

def run():
    try:
        num = int(input("Ingresa un numero:"))
        print(divisors(num))
        print("Termino mi programa")
    except ValueError:
        print("Debes ingresar un numero")


if __name__ == "__main__":
    run()
# Out:
# Ingresa un numero:-4
# No se puede ingresar numeros negativos
# False
# Termino mi programa

# %% [markdown]
# ### Assert Statement

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Como se interpreta: "Afirmo que esta condición es verdadera, sino imprime este mensaje de error"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def divisors(num):
    assert num>0, "El # debe ser igual o mayor a cero" 
    divisors = []
    for i in range(1, num +1):
        if num % i == 0:
            divisors.append(i)
    return divisors


def run():
    num = input("Ingresa un numero: ")
    assert num.isnumeric(), "Debes ingresar un numero" 
    print(divisors(int(num)))
    print("Termino mi programa")



if __name__ == "__main__":
    run()
# Out:
# Ingresa un numero: -4
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-d539afec535d> in <module>()
#      17
#      18 if __name__ == "__main__":
# ---> 19     run()
#
# <ipython-input-4-d539afec535d> in run()
#      10 def run():
#      11     num = input("Ingresa un numero: ")
# ---> 12     assert num.isnumeric(), "Debes ingresar un numero"
#      13     print(divisors(int(num)))
#      14     print("Termino mi programa")
#
# AssertionError: Debes ingresar un numero

# %% [markdown]
# ##9.Trabajando con archivos

# %% [markdown]
# Para abrir un arhivo tenemos la siguiente estructura:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - *with* Es un manejador contextual, nos ayuda a controlar el flujo del archivo (sirve para que el archivo no se dañe cuando existe algún cierre inesperado)
#
# - *open(ruta,modo_apertura)*: es una función que necesita de dos parámetros
#
# *ruta*: es donde se encuentra nuestro archivo en nuestro equipo
#
#
# modo_de_apertura: como vamos a abrir el archivo, los modificadores son:
#
# r → modo de lectura
#
# w → modo de escritura (sobreescribe el archivo)
#
# a → modo append (añade información al final del archivo)
#
#
# - as <nombre> nos ayuda a darle una abreviatura o un nombre a los datos que acabamos de leer

# %% [markdown]
# Para ejemplo ver archivo: archivos.py

# %%
for i in range(0 , 5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
