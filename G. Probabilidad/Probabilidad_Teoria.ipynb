# %% [markdown]
# # PROBABILIDAD

# %% [markdown]
# ##1.INTRODUCCIÓN

# %% [markdown]
# La probabilidad es una creencia que tenemos sobre la ocurrencia de eventos elementales.
#
# ¿En qué casos usamos la probabilidad?
#
# Intuitivamente, hacemos estimaciones de la probabilidad de que algo ocurra o no, al desconocimiento que tenemos sobre la información relevante de un evento lo llamamos incertidumbre.El azar en estos términos no existe, representa la ausencia del conocimiento de todas las variables que componen un sistema.
#
# En otras palabras, la probabilidad es un lenguaje que nos permite cuantificar la incertidumbre.

# %% [markdown]
# **AXIOMAS:**
#
# Es un conjunto de sentencias que no son derivables de algo más fundamental. Las damos por verdad y no requieren demostración.
#
# **AXIOMAS DE PROBABILIDAD**
#
# La probabilidad está dada por el número de casos de éxito sobre la cantidad total(teórica) de casos.
#
# - **P** = #-Casos de éxito/ # Casos-totales.
# - **Suceso elemental:** Es una única ocurrencia, “Solo tienes una cara de la moneda como resultado”
# - Sucesos: Son las posibilidades que tenemos en el sistema. Está compuesto de sucesos elementales,
# por ejemplo, “El resultado de lanzar un dado es par”, hay tres sucesos (2,4,6) que componen este enunciado.

# %% [markdown]
# Existen 2 tipos de escuelas: La Frecuentista y la Bayesiana.
#
# **ESCUELA FRECUENTISTA:**
#
# La probabilidad de ocurrencia en un espacio muestral ocurre bajo el supuesto de que la proporción de exitos/totales tiende a un valor p. En otras palabras, solo lanzando la moneda infinitas veces podemos advertir que el valor de la probabilidad es cercano a (1/2 o 50%).
#
# “Toda variable aleatoria viene descrita por el espacio muestral que contiene todos los posibles sucesos de ese problema aleatorio.”
#
# La probabilidad que se asigna como un valor a cada posible suceso tiene varias propiedades por cumplirse
#
# PROPIEDADES AXIOMAS:
# - 0 <= P <= 1
# - Certeza: P = 1
# - Imposibilidad P = 0
# - Disyunción P(AuB) = P(A) +P(B)

# %% [markdown]
# ##2.PROBABILIDAD EN MACHINE LEARNING

# %% [markdown]
# **FUENTES DE INCERTIDUMBRE**
#
# **- Datos:** Debido a que nuestros instrumentos de medición tienen un margen de error, se presentan datos imperfectos e incompletos, por lo tanto hay incertidumbre en los datos.
#
# **- Atributos del modelo:** Son variables que representan un subconjunto reducido de toda la realidad del problema, estas variables provienen de los datos y por lo tanto presentan cierto grado de incertidumbre.
#
# **- Arquitectura del modelo:** Un modelo en mates es una representación simplificada de la realidad y al ser así, por construcción, induce otra capa de incertidumbre, ya que al ser una representación simplificada se considera mucho menos información.

# %% [markdown]
# Toda esta incertidumbre se puede cuantificar con probabilidad:
#
# Ejemplo, un clasificador de documento de texto:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Entonces, el modelo asignara cierta probabilidad a cada documento y así de determinara la clasificación de los documentos.
#
# Pero, ¿cómo funciona por dentro nuestro modelo de clasificación?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##3.TIPOS DE PROBABILIDAD

# %% [markdown]
# *   Conjunta:  Cuando se calcula la probabilidad de 2 o mas sucesos. Ejemplo de tirar dos dados (Son eventos independientes).
# *   Condicional: Cuando la probabilidad a calcular se le impone una condición previa.
# *   Marginal: Cuando se obtiene una probabilidad sencilla a partir de una probabilidad conjunta.

# %% [markdown]
# PROBABILIDAD CONJUNTA: EJEMPLO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# PROBABILIDAD CONDICIONAL: EJEMPLO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La pregunta 2 es la que se refiere a probabilidad condicional

# %% [markdown]
# Cuando se tiene las probabilidades conjuntas de 2 sucesos y se quiere saber solo la probabilidad de que suceda el primer suceso independiente de lo que pasa con el otro, así eso se define como la suma de todas la probabilidades conjuntas sobre los demás estados que no está considerando A.
#
# La probabilidad marginal es la misma probabilidad de la regla del producto, pero la relación fundamental siempre será la regla del producto.
#
# Las probabilidad marginales se obtienen haciendo sumas sobre ciertas ocurrencias de ciertas variables aleatorias dentro de la probabilidad conjunta. Es decir, siempre que se hagan sumas de probabilidades conjuntas y se calcuale una sola variables (evento), entonces se dice que se esta calculando la probabilidad marginal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##4.DISTRIBUCIÓN

# %% [markdown]
# Una distribución de probabilidad es una función en el sentido matematico del calculo, que coge una variable aleatoria y a cada uno de sus posibles estados dentro del espacio muestreal le asigna una probabilidad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# X es una variable aleatoria donde P es la funci´n que a cada una de las ocurrencias o valores posibles de esta variable aleatoria, le va a asignar un numero que llamaremos Probabilidad. De esta manera, entendemos que P es una función de la variable aleatoria y por eso se copia P = f(x).
#
# Es importante tener en cuenta la notación matematica:
# - Cuando se escribe X (Mayuscula): Denota la variable.
# - Cuando se escribe x (minuscula): Denota valores posibles que las variables aleatorias pueden tomar.

# %% [markdown]
# FUNCIÓN DE PROBABILIDAD ACUMULADA
#
# Funciones continuas:
#
# La función de probabilidad acumulada es la integral de la función de densidad de probabilidad. Y sirve para responder las preguntas donde se pide la probabilidad de que el evento sea menor o mayor a determinado valor. Esto solo aplica para funciones continuas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Las funciones discretas se pintan mas con digrama de barras, mientras que las funciones continuas se grafican con la linea.

# %% [markdown]
# Funciones discretas:
#
# La función de probabilidad acumulada para funciones discretas se calcula con las sumas de las probabilidades discretas (Ya no integrales).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###4.1 DISTRIBUCIONES DISCRETAS

# %% [markdown]
# #### 4.1.1 Bernoulli

# %% [markdown]
# Permite describir ocurrencias con variables que son binarias (Como tirar una moneda).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####4.1.2 Distribución Binomial

# %% [markdown]
# Es una secuencia repetitiva de eventos tipo Bernoulli.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Siendo "n" el numero de lanzamientos y "k" el numero de exitos. La formula de la combinación, me da los estados exitosos solamente, ya despues de realiza la división por el espacio muestral que en este caso era de 8. En conclusión la formula de la distribución binomial seria la siguiente:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Propiedades de una distribución binomial:
#
# - Los sucesos son colectivamente exhaustivos, es decir, al menos uno de los 2 ha de ocurrir. Si no se es hombre, se es mujer y, si se lanza una moneda, si no sale cara ha de salir cruz.
#
# - La variable aleatoria que sigue una distribución binomial se suele representar como X~(n,p), donde n representa el número de ensayos o experimentos y p la probabilidad de éxito.
#
# - Los sucesos son mutuamente excluyentes, es decir, no pueden ocurrir los 2 al mismo tiempo. No se puede ser hombre y mujer al mismo tiempo o que al lanzar una moneda salga cara y cruz al mismo tiempo.

# %% [markdown]
# Otras distribuciones discretras:
# - Poisson.
# - Geometrica.
# - Hipergeometrica.
# - Binomial negativa.

# %% [markdown]
# ## 5.MLE (Maximum Likelihood estimation)

# %% [markdown]
# Técnica para estimar densidades de probabilidad dentro de un esquema de trabajo general.
#
# Elementos de MLE
# - Escoger la distribución: Teniendo solo una muestra de los datos.
# - Escoger los parametros de la distribución (Que mejor se ajustan a la distribución de datos).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Consiste en escoger la distribucion que más se ajuste a nuestros datos, para ello maximizamos la probabilidad de nuesto modelo:
# P(X,θ)=L(X,θ)
# max L(X,θ) → maxΠP(Xi,θ)
#
# Nota:
# El producto de mútiples probabilidades (por tanto son menores a 1) genera números cada vez más pequeños al punto que no son exactos para el PC (Ya que es una maquina con una precisión finita), a esto se llama underflow para evitar esta situacion usamos logaritmos:
#
# max log L(X,θ) → maxΣ log P(Xi,θ)
